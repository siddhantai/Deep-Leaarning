# %%
from keras.datasets import mnist
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train/255.0
x_test=x_test/255.0

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=(['accuracy']))

# %%
model.fit(x_train,y_train,epochs=10)
model.evaluate(x_test,y_test)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0422 - accuracy: 0.9860
# Epoch 2/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0389 - accuracy: 0.9868
# Epoch 3/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0366 - accuracy: 0.9874
# Epoch 4/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0341 - accuracy: 0.9880
# Epoch 5/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0332 - accuracy: 0.9888
# Epoch 6/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0311 - accuracy: 0.9896
# Epoch 7/10
# 60000/60000 [==============================] - 7s 118us/sample - loss: 0.0311 - accuracy: 0.9884
# Epoch 8/10
# 60000/60000 [==============================] - 7s 119us/sample - loss: 0.0280 - accuracy: 0.9905
# Epoch 9/10
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.0283 - accuracy: 0.9900
# Epoch 10/10
# 60000/60000 [==============================] - 7s 122us/sample - loss: 0.0254 - accuracy: 0.9911
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07996807743897807, 0.9815]
